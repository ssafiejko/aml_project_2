# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_classif
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
import warnings
from utils import ModelComparator, ModelEnsemble
from mlp import MLPClassifier
from xgboost import XGBClassifier
warnings.filterwarnings(action="ignore")

# %%
X = pd.read_table('x_train.txt', sep=" ", header=None)
X.columns = [str(i) for i in range(X.shape[1])]
y = pd.read_table('y_train.txt', header=None).to_numpy(dtype=np.int8).squeeze()

# %%
comparator = ModelComparator(X, y, n_splits=15)

# %% [markdown]
# # Initial results

# %%
from sklearn.linear_model import LogisticRegression

# %%
comparator = ModelComparator(X, y, n_splits=15)
criterion = comparator.evaluate_model(SVC(probability=True),
                          [2, 414, 462]) # If None, calculates with all variables
# Out:
# Test Accuracies (Overall): 0.72 ± 0.02

# %% [markdown]
# ### Example with custom MLP classifier

# %%
model_mlp = MLPClassifier(epochs=10, lr=0.001, weight_decay=0, batch_size=64)

comparator.evaluate_model(model_mlp,
                          variables=[2, 81, 28, 209, 180, 414, 462, 300, 351, 425]) # This method also returns Acc@20%
# Out:
# Test Accuracies (Overall): 0.72 ± 0.01
# 0.7326732673267325

# %% [markdown]
# ### Example with an ensemble

# %%
# model_mlp = MLPClassifier(epochs=8, lr=0.002, weight_decay=0.0001, batch_size=64)
gb = XGBClassifier(n_estimators=50)
# rf = RandomForestClassifier(n_estimators=20, criterion="entropy")
lr = LogisticRegression(penalty="l2", C=0.01, solver="liblinear")

ensemble = ModelEnsemble(models=(lr,), voting="mean")


comparator.evaluate_model(ensemble,
                          variables=top_mi_features[:20]) # This method also returns Acc@20%
# Out:
# Test Accuracies (Overall): 0.66 ± 0.02
# 0.7264705882352939

# %% [markdown]
# # Feature selection

# %% [markdown]
# Will be performed independently from original column names, for example: <br>
# `Selected features = [0, 5, 440]` may in fact be `[1, 7, 468]` from original dataset

# %% [markdown]
# ## VIF

# %% [markdown]
# Performed iteratively according to methodology:
# 1. calculate VIF of every variable and choose those with `VIF > 5`
# 2. Among those found in point 1, remove this variable with **lowest** Mutual Information Score (with relation to target `y`)

# %%
# Only results of this method provided (it is computationally expensive)
from utils import VIF_SELECTED_VARIABES

print(VIF_SELECTED_VARIABES)
# Out:
# [13, 178, 194, 298, 305, 117, 228, 462, 414, 425, 0, 1, 3, 4, 5, 6, 7, 8, 9]

# %%
# Note: This deletion will change columns order! (col 2 becomes 0, for example)
#       Perform it only ONCE!
# X = np.delete(X, VIF_SELECTED_VARIABES, axis=1)

# print(X.shape)
# Out:
# (5000, 481)

# %% [markdown]
# ## ANOVA F-test

# %%
from sklearn.feature_selection import f_classif

# %%
F_statistic_values, p_values = f_classif(X, y)

top_f_test_features = np.argsort(p_values)
bottom_f_test_features = np.argsort(p_values)[::-1]
plt.figure(dpi=120, figsize=(5,5))
plt.hist(p_values, edgecolor='black', linewidth=1.2, color="orange", bins=40)
plt.title("ANOVA F-test p values distribution")
plt.show()

# %%
top_f_test_features
# Out:
# array([  2,   3,   6,   7,   4,   8,   5,   0,   1,   9, 414, 462, 425,
#        458, 351, 339, 395, 170, 180, 356, 300, 215, 140, 293, 344, 343,
#        366, 336, 330, 332, 294, 237, 446, 285, 176,  41, 387, 133, 109,
#        253, 158, 459, 126,  47,  76, 117,  92, 201,  86, 231, 157, 146,
#        274, 163, 430, 463,  73, 325, 150,  77, 358, 355,  90,  33,  88,
#         97, 263, 422, 436, 367, 209, 405, 401, 477, 226,  71, 152, 318,
#        440, 183,  36, 479, 371, 186,  55, 286, 223, 460,  96, 121, 213,
#        297, 281, 214, 323, 155, 220, 346, 217, 475, 262, 494, 169, 485,
#        127,  93, 338,  24, 421, 206, 434, 191, 134,  64, 372, 315, 309,
#         46, 198, 268, 123, 137, 287, 368, 202, 481, 444, 365, 135, 320,
#        267, 173, 348, 218, 433, 397,  74,  51, 115, 399, 312, 375, 148,
#        139, 101, 103, 197, 275, 498, 219, 451, 184, 353, 185,  37, 108,
#        114, 232, 251, 441, 439, 471, 394, 402, 363, 200, 131, 389, 324,
#         81, 249, 298, 334, 257, 171, 496, 398, 391, 246,  87, 374, 290,
#        406, 416, 454, 147,  44, 238, 314, 489, 329, 248, 411, 443, 342,
#        167, 303, 241, 182,  48, 205, 208, 437,  11,  99, 472,  31,  13,
#        203, 107, 187, 473, 113,  89, 195, 400, 499, 179, 122, 304, 279,
#        142, 495, 488, 487, 288, 306, 452, 124, 172,  30, 192, 476,  14,
#        369, 461, 453, 470, 445, 364,  80, 234, 261, 266, 105, 386,  72,
#        390,  26, 420,  50, 145, 335, 410, 193, 264, 450, 467, 168, 484,
#         38, 310,  70, 357, 269, 292, 492, 222,  12, 404, 154, 156, 417,
#        229, 447, 313, 164, 277, 478, 271,  35,  61, 225, 429,  95, 250,
#         49, 345, 235, 283, 415,  54, 228, 483, 412, 295,  59, 136, 469,
#        305, 311,  18, 211, 350, 474, 178,  66, 119, 321, 482, 491, 259,
#        359, 418, 354, 141, 435, 181,  91, 328, 289, 403, 245, 110, 116,
#         25, 175,  15, 465, 177, 240, 291, 284, 381, 166, 104,  20, 190,
#        349, 468, 360, 302, 256, 319,  68, 149, 255,  29, 270, 273,  57,
#        307, 260, 280, 419, 497, 493,  58, 373,  17,  69, 377, 327, 362,
#         39, 392, 426, 159, 194, 196,  23, 199, 188, 409, 174, 224, 352,
#        189, 490,  32, 254,  19, 455, 378, 308, 265,  65, 432,  27, 210,
#        337, 100,  83, 331, 153, 317,  22, 341, 347, 301, 486,  60, 227,
#        128,  82,  62, 272,  67, 243, 316, 120, 480, 340, 144, 102, 216,
#        112,  42, 130,  63, 207, 204, 407, 384, 162, 424,  78, 212,  43,
#        242, 258, 427, 413,  84, 236,  85,  56, 396,  21, 408, 438, 165,
#         52, 361, 106, 252,  45,  79, 385, 376, 383, 379, 276,  16, 138,
#         34, 299, 423, 129, 247,  98, 380, 244, 151,  94, 456, 442, 322,
#        132, 278, 125, 326, 464, 333, 233,  10, 457, 382, 239, 393, 449,
#         40,  75, 388, 118, 221, 143,  28, 160, 428, 161, 431, 230, 370,
#        282, 466,  53, 448, 296, 111])

# %% [markdown]
# ## ReliefF

# %%
from skrebate import ReliefF

# %%
relief = ReliefF(n_neighbors=10, n_features_to_select=10)
relief.fit(np.array(X), y)

top_relief_features = relief.top_features_
bottom_relief_features = top_relief_features[::-1]

plt.hist(relief.feature_importances_, edgecolor='black', bins=50, linewidth=1.2)
plt.title("ReliefF feature importances distribution")
plt.show()

# %%
relief.top_features_
# Out:
# array([  2,   3,   6,   7,   4,   8,   5,   0,   1, 414,   9, 462, 425,
#        354, 300, 360, 388, 322, 311, 344, 331, 343, 177, 368, 437, 466,
#        279, 329, 310, 172, 320, 154, 386, 497, 323,  60, 147,  31, 121,
#        146, 371,  41, 194,  48, 404, 476,  81, 133, 302, 131, 346,  50,
#        362, 270, 298, 307, 306, 182, 113,  43, 324, 184,  91, 473, 389,
#        339, 142, 488,  66,  11,  76, 229,  75, 192, 478, 251, 125, 211,
#        482, 348,  82, 465, 283, 461, 415,  57, 190, 152, 119, 238,  58,
#        313, 359, 185, 225, 493, 215, 101, 228, 241, 378, 430, 135,  25,
#        447, 419, 372,  89, 260, 407, 314, 290, 107, 383, 165, 263, 457,
#        216, 227, 198,  86, 266, 122, 487,  22,  47, 342, 201,  15, 271,
#         42, 284,  95, 143, 434, 416, 424,  10, 223, 139,  96,  94, 112,
#         18, 334, 491, 451, 398, 445, 111, 179, 358, 413, 237, 400, 220,
#        235, 428, 382, 244, 137, 219, 249,  28,  68,  30, 335, 355, 103,
#        446, 401, 163, 484, 485, 489, 258, 155,  59, 422, 174,  14,  88,
#        169, 141, 178,  71, 409, 291, 262, 124, 318,  45, 463, 202, 191,
#        442, 252, 242,  29, 196,  20, 200,  78, 453, 277, 282,  61, 459,
#        496, 397, 366, 399, 208, 299, 475,  90, 417, 140, 212, 421, 234,
#        170, 173, 392, 268, 193, 458, 207, 150, 293, 443, 126, 281, 175,
#         19, 187, 408,  65, 255,  13, 474, 132,  33,  32,  23,  55, 226,
#        272, 352,  99, 312, 431, 116, 287,  80, 209, 127, 106, 239, 134,
#        253, 269,  98, 156, 486, 245, 136, 213,  44, 236, 468, 304, 171,
#        183,  52, 367, 405, 444, 199, 469,  62, 248,  51, 384, 243, 441,
#        297, 158, 440,  92, 406,  97, 117, 454, 159, 439, 377,  87, 498,
#         54, 276, 275, 254, 403,  79, 288, 325, 104, 114, 256,  69,  37,
#        280, 230,  74,  38, 483, 452,  24,  16, 332, 189, 168, 257, 402,
#        472, 450, 381,  40,  26, 118, 296, 217, 161, 448, 267, 436, 265,
#        259, 102,  72, 128, 309, 167, 246, 336, 100,  39, 286, 285, 138,
#        231, 210, 423,  56, 356, 148, 480, 317, 412, 221, 364,  85, 438,
#        186, 333, 387, 464, 204, 115, 261, 490,  64, 188, 391, 214, 370,
#        250, 375, 145, 351, 166, 492,  46,  49, 477, 456, 157, 224, 222,
#        180, 494, 218, 195, 203,  53, 361, 349, 181, 479, 455, 467, 289,
#        353,  84, 427, 232,  21, 338, 385, 130, 357, 495, 481, 123,  34,
#        330, 411, 240, 470, 197, 153, 274, 176,  36, 420,  70, 149, 435,
#        394, 233,  77, 162, 264, 164, 418, 347, 151, 499, 350,  17, 328,
#        108, 205, 316, 110, 395, 109, 396, 433, 341, 429, 144,  27,  73,
#        449, 426, 337, 120, 410, 273, 393, 460, 295, 432, 315, 301, 379,
#        247, 308, 471,  67,  35, 129, 373, 292,  83, 365, 105, 206, 376,
#        326, 340, 278, 305,  93, 160,  63,  12, 321, 303, 363, 345, 374,
#        390, 294, 369, 380, 327, 319])

# %% [markdown]
# ## Mutual Information

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mi = mutual_info_classif(X,y, n_neighbors=10)
top_mi_features = np.argsort(mi)[::-1]
bottom_mi_features = top_mi_features[::-1]

# %%
pd.Series(mi).hist(bins=100)
# Out:
# <Axes: >

# %%
top_mi_features[:150]
# Out:
# array([  2,   3,   6,   8,   7,   4,   5,   1,   0,   9, 462, 414, 425,
#        405, 127, 262, 210, 409, 468, 146, 279, 432, 362, 302, 241, 237,
#        122,  45, 117, 454, 424, 369, 386, 175, 102, 295, 198, 389, 370,
#        244, 442, 276, 481, 375, 115, 269, 298, 163, 287, 251,  24,  28,
#        320, 284, 296, 188,  85,  76, 285, 226, 158, 178, 319, 186, 486,
#        242, 460,  53, 184,  31, 290, 179, 428, 495, 323, 395, 340, 314,
#         64, 372, 126, 446, 479, 463, 106,  83, 408,  48, 234, 337, 281,
#        121, 338, 260, 484, 205,  38, 357, 466, 225, 358, 497, 245, 356,
#        322,  75, 108, 376, 416,  65, 343, 236, 216, 360, 342,  52, 164,
#        431, 203, 300, 201, 277, 151, 215, 423, 149,  99, 135, 247, 171,
#        132, 368, 306, 382, 189, 438, 253, 316, 333, 191,  60, 235, 197,
#        452, 348, 485,  61, 494, 291, 133])

# %%
common_bottom_n = 300

common_worst = list(
    set.intersection(
        set(bottom_f_test_features[:common_bottom_n]),
        set(bottom_mi_features[:common_bottom_n]),
        set(bottom_relief_features[:common_bottom_n])
    ))

common_worst.sort()

print(f'Common worst {common_bottom_n} variables: {len(common_worst)}')
# Out:
# Common worst 300 variables: 122

# %% [markdown]
# ## MARS

# %% [markdown]
# Works only with Python $\leq$ 3.10, so doing it through `R`, posting the results below only <br>
# `R` indices are from 1, so Python equivalent is 1 less (V3 $\rightarrow$ 2, V9 $\rightarrow$ 8 etc.) <br> <br>
# *MARS was done `without` data scaling, but it should not impact the output severely*

# %% [markdown]
# ### Including VIF-removed variables

# %%
########################################
# MARS (degree = 1)
#      nsubsets   gcv    rss
# V3         13 100.0  100.0
# V9         11  27.6   32.6
# V463       10  27.4   32.0
# V5          9  25.4   29.8
# V352        8  19.4   24.6
# V255        7  17.1   22.2
# V29         5  12.7   17.5
# V486        4  10.1   14.8
# V56         3   7.2   11.9
########################################
# MARS (degree = 2)
#      nsubsets   gcv    rss
# V3         19 100.0  100.0
# V415       17  42.1   47.3
# V463       16  37.3   43.0
# V426       15  31.5   37.9
# V352       14  27.4   34.3
# V5         13  25.6   32.4
# V56        12  23.7   30.5
# V406       12  23.7   30.5
# V483       11  21.9   28.6
# V116       10  19.8   26.6
# V218        9  17.7   24.4
# V454        8  15.1   22.0
# V345        7  12.0   19.3
# V388        4   4.5   12.5
########################################

# %% [markdown]
# ### Excluding VIF-removed variables

# %%
########################################
# MARS (degree = 1)
#      nsubsets   gcv    rss
# V3         13 100.0  100.0
# V352       11  22.6   28.9
# V406       10  20.6   26.9
# V29         9  18.9   25.0
# V210        8  17.4   23.2
# V380        7  15.7   21.3
# V82         6  13.9   19.3
# V255        5  11.8   17.0
# V486        4   9.4   14.5
# V56         3   6.6   11.7
########################################
# MARS (degree = 2)
#      nsubsets   gcv    rss
# V3         22 100.0  100.0
# V23        20  32.9   41.2
# V255       20  32.9   41.2
# V444       19  30.6   39.1
# V352       18  28.9   37.4
# V454       17  27.3   35.7
# V218       16  25.7   34.1
# V29        15  24.1   32.5
# V406       15  24.1   32.5
# V82        14  22.5   30.9
# V76        13  21.0   29.3
# V349       12  19.5   27.7
# V234       11  18.0   26.1
# V443        9  14.4   22.4
# V75         7  12.3   19.6
# V61         6  10.6   17.6
# V49         4   6.7   13.4
# V339        2   6.1   10.2
########################################

# %% [markdown]
# ### Excluding VIF-removed variables and {2}

# %%
########################################
# MARS (degree = 1)
#      nsubsets   gcv    rss
# X210       14 100.0  100.0
# X82        13  92.4   94.4
# X344       12  84.1   88.5
# X255       11  77.5   83.4
# X209       10  69.9   77.7
# X56         9  61.8   71.8
# X189        7  52.3   62.4
# X396        5  46.3   53.6
# X202        4  38.5   46.7
# X368        2  25.1   32.2
########################################
# MARS (degree = 2)
# X255       18 100.0  100.0
# X394       18 100.0  100.0
# X56        17  94.4   95.5
# X388       17  94.4   95.5
# X444       16  88.8   91.1
# X286       15  83.1   86.6
# X33        14  77.2   81.9
# X234       13  70.2   76.7
# X210       11  59.5   67.9
# X82        11  59.0   67.6
# X459       11  59.0   67.6
# X261        9  48.0   58.6
# X483        8  42.6   54.0
# X371        6  33.8   45.4
# X242        4  29.1   37.7
# X396        3  22.3   31.4
# X301        2  15.5   24.6
